# %% [markdown]
# #Requests
# The Spotify Web API is based on REST principles. Data resources are accessed via standard HTTPS requests in UTF-8 format to an API endpoint. Where possible, Web API uses appropriate HTTP verbs for each action:
#
# METHOD	ACTION
# GET	Retrieves resources
# POST	Creates resources
# PUT	Changes and/or replaces resources or collections
# DELETE	Deletes resources
# Spotify URIs and IDs
# In requests to the Web API and responses from it, you will frequently encounter the following parameters:
#
# PARAMETER	DESCRIPTION	EXAMPLE
# Spotify URI	The resource identifier that you can enter, for example, in the Spotify Desktop client’s search box to locate an artist, album, or track. To find a Spotify URI simply right-click (on Windows) or Ctrl-Click (on a Mac) on the artist’s or album’s or track’s name.	spotify:track:6rqhFgbbKwnb9MLmUQDhG6
# Spotify ID	The base-62 identifier that you can find at the end of the Spotify URI (see above) for an artist, track, album, playlist, etc. Unlike a Spotify URI, a Spotify ID does not clearly identify the type of resource; that information is provided elsewhere in the call.	6rqhFgbbKwnb9MLmUQDhG6
# Spotify category ID	The unique string identifying the Spotify category.	party
# Spotify user ID	The unique string identifying the Spotify user that you can find at the end of the Spotify URI for the user. The ID of the current user can be obtained via the Web API endpoint.	wizzler
# Spotify URL	An HTML link that opens a track, album, app, playlist or other Spotify resource in a Spotify client (which client is determined by the user’s device and account settings at play.spotify.com.	http://open.spotify.com/track/6rqhFgbbKwnb9MLmUQDhG6
# Rate Limiting
# Rate Limiting enables Web API to share access bandwidth to its resources equally across all users.
#
# Rate limiting is applied as per application based on Client ID, and regardless of the number of users who use the application simultaneously.
#
# To reduce the amount of requests, use endpoints that fetch multiple entities in one request. For example: If you often request single tracks, albums, or artists, use endpoints such as Get Several Tracks, Get Several Albums or Get Several Artists, instead.
#
# Note: If Web API returns status code 429, it means that you have sent too many requests. When this happens, check the Retry-After header, where you will see a number displayed. This is the number of seconds that you need to wait, before you try your request again.
#
# Responses
# Web API returns all response data as a JSON object. See the Web API Object Model for a description of all the retrievable objects.
#
# Timestamps
# Timestamps are returned in ISO 8601 format as Coordinated Universal Time (UTC) with a zero offset: YYYY-MM-DDTHH:MM:SSZ. If the time is imprecise (for example, the date/time of an album release), an additional field indicates the precision; see for example, release_date in an album object.
#
# Pagination
# Some endpoints support a way of paging the dataset, taking an offset and limit as query parameters:
#
# $ curl
# https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6/albums?album_type=SINGLE&offset=20&limit=10
# In this example, in a list of 50 (total) singles by the specified artist : From the twentieth (offset) single, retrieve the next 10 (limit) singles.
#
# Note: The offset numbering is zero-based. Omitting the offset parameter returns the first X elements. Check the documentation for the specific endpoint and verify the default limit value. Requests that return an array of items are automatically paginated if the number of items vary. For example, tracks in a playlist. In such case, the results are returned within a paging object.
#
# Conditional Requests
# Most API responses contain appropriate cache-control headers set to assist in client-side caching:
#
# If you have cached a response, do not request it again until the response has expired.
# If the response contains an ETag, set the If-None-Match request header to the ETag value.
# If the response has not changed, the Spotify service responds quickly with 304 Not Modified status, meaning that your cached version is still good and your application should use it.
# Note: To target changes to a particular historical playlist version and have those changes rolled through to the latest version, use playlist endpoints that also return a snapshot-id. For further information, see Working With Playlists.
#
# Response Status Codes
# Web API uses the following response status codes, as defined in the RFC 2616 and RFC 6585:
#
# STATUS CODE	DESCRIPTION
# 200	OK - The request has succeeded. The client can read the result of the request in the body and the headers of the response.
# 201	Created - The request has been fulfilled and resulted in a new resource being created.
# 202	Accepted - The request has been accepted for processing, but the processing has not been completed.
# 204	No Content - The request has succeeded but returns no message body.
# 304	Not Modified. See Conditional requests.
# 400	Bad Request - The request could not be understood by the server due to malformed syntax. The message body will contain more information; see Response Schema.
# 401	Unauthorized - The request requires user authentication or, if the request included authorization credentials, authorization has been refused for those credentials.
# 403	Forbidden - The server understood the request, but is refusing to fulfill it.
# 404	Not Found - The requested resource could not be found. This error can be due to a temporary or permanent condition.
# 429	Too Many Requests - Rate limiting has been applied.
# 500	Internal Server Error. You should never receive this error because our clever coders catch them all … but if you are unlucky enough to get one, please report it to us through a comment at the bottom of this page.
# 502	Bad Gateway - The server was acting as a gateway or proxy and received an invalid response from the upstream server.
# 503	Service Unavailable - The server is currently unable to handle the request due to a temporary condition which will be alleviated after some delay. You can choose to resend the request again.
# Response Schema
# Web API uses two different formats to describe an error:
#
# Authentication Error Object
# Regular Error Object
# Authentication Error Object
# Whenever the application makes requests related to authentication or authorization to Web API, such as retrieving an access token or refreshing an access token, the error response follows RFC 6749 on the OAuth 2.0 Authorization Framework.
#
# KEY	VALUE TYPE	VALUE DESCRIPTION
# error	string	A high level description of the error as specified in RFC 6749 Section 5.2.
# error_description	string	A more detailed description of the error as specified in RFC 6749 Section 4.1.2.1.
# Here is an example of a failing request to refresh an access token.
#
# $ curl -H "Authorization: Basic Yjc...cK" -d grant_type=refresh_token -d refresh_token=AQD...f0 "https://accounts.spotify.com/api/token"
#
# {
#     "error": "invalid_client",
#     "error_description": "Invalid client secret"
# }
# Regular Error Object
# Apart from the response code, unsuccessful responses return a JSON object containing the following information:
#
# KEY	VALUE TYPE	VALUE DESCRIPTION
# status	integer	The HTTP status code that is also returned in the response header. For further information, see Response Status Codes.
# message	string	A short description of the cause of the error.
# Here, for example is the error that occurs when trying to fetch information for a non-existent track:
#
# $ curl -i "https://api.spotify.com/v1/tracks/2KrxsD86ARO5beq7Q0Drfqa"
#
# HTTP/1.1 400 Bad Request
# {
#     "error": {
#         "status": 400,
#         "message": "invalid id"
#     }
# }
#
# Authentication
# All requests to Web API require authentication. This is achieved by sending a valid OAuth access token in the request header. For more information about these authentication methods, see the Web API Authorization Guide.

# %%
clientid = 'a2b4005538904434809bf1a8974f3eb7'
clientsecret = 'ea77d14c398e41d394fdcf94c1c79347'

# %% [markdown]
# https://spotipy.readthedocs.io/en/latest/#installation
#
# pip install spotipy --upgrade
# pip install spotipy --use-feature=2020=-resolver

# %% [markdown]
# AudioFeaturesObject
# KEY	TYPE
# acousticness
# A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.	Float
# analysis_url
# An HTTP URL to access the full audio analysis of this track. An access token is required to access this data.	String
# danceability
# Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.	Float
# duration_ms
# The duration of the track in milliseconds.	Integer
# energy
# Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.	Float
# id
# The Spotify ID for the track.	String
# instrumentalness
# Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.	Float
# key
# The key the track is in. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on.	Integer
# liveness
# Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.	Float
# loudness
# The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.	Float
# mode
# Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.	Integer
# speechiness
# Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.	Float
# tempo
# The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.	Float
# time_signature
# An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure).	Integer
# track_href
# A link to the Web API endpoint providing full details of the track.	String
# type
# The object type: “audio_features”	String
# uri
# The Spotify URI for the track.	String
# valence
# A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(client_id=clientid, client_secret=clientsecret))

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Young Heart
# Beautiful Lies
# Beautiful Lies
# Beautiful Lies (Deluxe)
# Beautiful Lies (Deluxe)
# Fire Within
# Fire Within
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Fire Within (Deluxe)
# Live in London
# Birdy
# Birdy
# Birdy
# Birdy
# Birdy (Deluxe Version)

# %%
# shows acoustic features for tracks for the given artist

from __future__ import print_function    # (at top of module)
from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import sys


client_credentials_manager = SpotifyClientCredentials(client_id=clientid, client_secret=clientsecret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace = False

#if len(sys.argv) > 1:
#    artist_name = ' '.join(sys.argv[1:])
#else:
artist_name = 'Aaron Thompson'

results = sp.search(q=artist_name, limit=50)
tids = []
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])
    tids.append(t['uri'])

start = time.time()
features = sp.audio_features(tids)
features
# delta = time.time() - start
# for feature in features:
#     print(json.dumps(feature, indent=4))
#     print()
#     analysis = sp._get(feature['analysis_url'])
#     print(json.dumps(analysis, indent=4))
#     print()
# print("features retrieved in %.2f seconds" % (delta,))
# Out:
#   0 Alchemy
#   1 Honeys in the Place
#   2 You Know
#   3 Pulse
#   4 Colour
#   5 An Outdoor Overture
#   6 Blessed One
#   7 Pulse - Acoustic Version
#   8 Come Along with Me
#   9 I'm a Vip
#   10 Lord of All Hopefulness
#   11 10,000 Angels
#   12 Blessed One
#   13 No More
#   14 Drive
#   15 Santa Monica - Stripped
#   16 Poison Well
#   17 Nobody Loves You Like I Do
#   18 Ceremonial Fanfare
#   19 I Surrender (feat. Ryan McGrath & Aaron Thompson)
#   20 Bless Us for the Journey (feat. Kari Hanson, Aaron Thompson & Ryan McGrath)
#   21 Back to You (feat. Aaron Thompson, Chris "Topher" Aderhold, Camp Gray Choir & Ryan McGrath)
#   22 Light the Fire (feat. Ryan McGrath, Aaron Thompson, Chris "Topher" Aderhold & Camp Gray Choir)
#   23 Aaron's Boogie
#   24 Aaron Harris
#   25 Hail Holy Queen (feat. Nicky Kaehler, Kari Hanson, Ryan McGrath, Aaron Thompson & Chris "Topher" Aderhold)
#   26 The View from Mrs. Thompson's
#   27 Where I Wanna Be (The Camp Gray Song) [feat. Ryan McGrath, Chris "Topher" Aderhold, Camp Gray Choir & Aaron Thompson]
#   28 On the Rise - Aaron Waves Remix
#   29 On the Rise - Aaron Waves Remix
#   30 On the Rise - Aaron Waves Remix
#   31 On the Rise - Aaron Waves Remix
#   32 On the Rise - Aaron Waves Remix
#   33 On the Rise - Aaron Waves Remix
#   34 Sad Mona Lisa
#   35 Den Of The Wolves
#   36 Grey Highway
#   37 Bethany Lane
#   38 Houses In Water
#   39 A Record, A Wheel
#   40 Island Creek
#   41 Solitude
#   42 The Garden & The Road
#   43 Don't Say You Love
#   44 Vals
#   45 Runner
#   46 Every Nation on Earth
#   47 Awestruck
#   48 Great and Eternal God
#   49 Be Joyful Mary
# [{'danceability': 0.684,
#   'energy': 0.749,
#   'key': 5,
#   'loudness': -6.463,
#   'mode': 0,
#   'speechiness': 0.0654,
#   'acousticness': 0.0415,
#   'instrumentalness': 0.826,
#   'liveness': 0.272,
#   'valence': 0.656,
#   'tempo': 90.143,
#   'type': 'audio_features',
#   'id': '3wVUiPGvtz01ThUNS97wMj',
#   'uri': 'spotify:track:3wVUiPGvtz01ThUNS97wMj',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wVUiPGvtz01ThUNS97wMj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wVUiPGvtz01ThUNS97wMj',
#   'duration_ms': 244391,
#   'time_signature': 4},
#  {'danceability': 0.832,
#   'energy': 0.886,
#   'key': 6,
#   'loudness': -6.323,
#   'mode': 0,
#   'speechiness': 0.298,
#   'acousticness': 0.0362,
#   'instrumentalness': 0,
#   'liveness': 0.375,
#   'valence': 0.712,
#   'tempo': 109.921,
#   'type': 'audio_features',
#   'id': '6y0bIamBR0FNCP9X2xZ73z',
#   'uri': 'spotify:track:6y0bIamBR0FNCP9X2xZ73z',
#   'track_href': 'https://api.spotify.com/v1/tracks/6y0bIamBR0FNCP9X2xZ73z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0bIamBR0FNCP9X2xZ73z',
#   'duration_ms': 166759,
#   'time_signature': 4},
#  {'danceability': 0.404,
#   'energy': 0.546,
#   'key': 8,
#   'loudness': -9.48,
#   'mode': 0,
#   'speechiness': 0.0277,
#   'acousticness': 0.352,
#   'instrumentalness': 0.391,
#   'liveness': 0.0996,
#   'valence': 0.166,
#   'tempo': 142.099,
#   'type': 'audio_features',
#   'id': '0mPaSxhJ9GgAklB9jynawC',
#   'uri': 'spotify:track:0mPaSxhJ9GgAklB9jynawC',
#   'track_href': 'https://api.spotify.com/v1/tracks/0mPaSxhJ9GgAklB9jynawC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mPaSxhJ9GgAklB9jynawC',
#   'duration_ms': 207893,
#   'time_signature': 4},
#  {'danceability': 0.403,
#   'energy': 0.503,
#   'key': 9,
#   'loudness': -8.42,
#   'mode': 1,
#   'speechiness': 0.0374,
#   'acousticness': 0.557,
#   'instrumentalness': 0.00108,
#   'liveness': 0.111,
#   'valence': 0.11,
#   'tempo': 139.893,
#   'type': 'audio_features',
#   'id': '1s6FsthRerb3Ygcrqvz5eX',
#   'uri': 'spotify:track:1s6FsthRerb3Ygcrqvz5eX',
#   'track_href': 'https://api.spotify.com/v1/tracks/1s6FsthRerb3Ygcrqvz5eX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1s6FsthRerb3Ygcrqvz5eX',
#   'duration_ms': 226286,
#   'time_signature': 4},
#  {'danceability': 0.598,
#   'energy': 0.534,
#   'key': 11,
#   'loudness': -10.514,
#   'mode': 0,
#   'speechiness': 0.0327,
#   'acousticness': 0.244,
#   'instrumentalness': 0.075,
#   'liveness': 0.103,
#   'valence': 0.195,
#   'tempo': 120.026,
#   'type': 'audio_features',
#   'id': '45TY2PWrL1XiuCkdbd5S1J',
#   'uri': 'spotify:track:45TY2PWrL1XiuCkdbd5S1J',
#   'track_href': 'https://api.spotify.com/v1/tracks/45TY2PWrL1XiuCkdbd5S1J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45TY2PWrL1XiuCkdbd5S1J',
#   'duration_ms': 215093,
#   'time_signature': 4},
#  {'danceability': 0.308,
#   'energy': 0.0866,
#   'key': 2,
#   'loudness': -22.149,
#   'mode': 0,
#   'speechiness': 0.0462,
#   'acousticness': 0.96,
#   'instrumentalness': 0.898,
#   'liveness': 0.049,
#   'valence': 0.228,
#   'tempo': 84.824,
#   'type': 'audio_features',
#   'id': '18UUvBTZvCtdx7iiv28Nzp',
#   'uri': 'spotify:track:18UUvBTZvCtdx7iiv28Nzp',
#   'track_href': 'https://api.spotify.com/v1/tracks/18UUvBTZvCtdx7iiv28Nzp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18UUvBTZvCtdx7iiv28Nzp',
#   'duration_ms': 558280,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.29,
#   'key': 4,
#   'loudness': -13.989,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.17,
#   'instrumentalness': 5.86e-06,
#   'liveness': 0.181,
#   'valence': 0.403,
#   'tempo': 139.955,
#   'type': 'audio_features',
#   'id': '115UwbIlFzJiCwwxqsF5J4',
#   'uri': 'spotify:track:115UwbIlFzJiCwwxqsF5J4',
#   'track_href': 'https://api.spotify.com/v1/tracks/115UwbIlFzJiCwwxqsF5J4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/115UwbIlFzJiCwwxqsF5J4',
#   'duration_ms': 207667,
#   'time_signature': 3},
#  {'danceability': 0.44,
#   'energy': 0.209,
#   'key': 9,
#   'loudness': -11.959,
#   'mode': 1,
#   'speechiness': 0.0432,
#   'acousticness': 0.571,
#   'instrumentalness': 6.85e-05,
#   'liveness': 0.142,
#   'valence': 0.0921,
#   'tempo': 55.036,
#   'type': 'audio_features',
#   'id': '6ReHAadU7V0b3tPOuvWjUy',
#   'uri': 'spotify:track:6ReHAadU7V0b3tPOuvWjUy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ReHAadU7V0b3tPOuvWjUy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ReHAadU7V0b3tPOuvWjUy',
#   'duration_ms': 207429,
#   'time_signature': 5},
#  {'danceability': 0.541,
#   'energy': 0.92,
#   'key': 9,
#   'loudness': -7.149,
#   'mode': 1,
#   'speechiness': 0.0382,
#   'acousticness': 0.0235,
#   'instrumentalness': 0.117,
#   'liveness': 0.101,
#   'valence': 0.946,
#   'tempo': 141.001,
#   'type': 'audio_features',
#   'id': '5M9LV2bUvuG47TFEA2A4kO',
#   'uri': 'spotify:track:5M9LV2bUvuG47TFEA2A4kO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5M9LV2bUvuG47TFEA2A4kO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5M9LV2bUvuG47TFEA2A4kO',
#   'duration_ms': 202453,
#   'time_signature': 4},
#  {'danceability': 0.754,
#   'energy': 0.911,
#   'key': 11,
#   'loudness': -7.21,
#   'mode': 0,
#   'speechiness': 0.152,
#   'acousticness': 0.014,
#   'instrumentalness': 0,
#   'liveness': 0.368,
#   'valence': 0.655,
#   'tempo': 99.992,
#   'type': 'audio_features',
#   'id': '2F3vj4YtpE7gvPmYpDtMPt',
#   'uri': 'spotify:track:2F3vj4YtpE7gvPmYpDtMPt',
#   'track_href': 'https://api.spotify.com/v1/tracks/2F3vj4YtpE7gvPmYpDtMPt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2F3vj4YtpE7gvPmYpDtMPt',
#   'duration_ms': 161956,
#   'time_signature': 4},
#  {'danceability': 0.361,
#   'energy': 0.172,
#   'key': 3,
#   'loudness': -14.433,
#   'mode': 1,
#   'speechiness': 0.0347,
#   'acousticness': 0.957,
#   'instrumentalness': 0.0193,
#   'liveness': 0.102,
#   'valence': 0.0732,
#   'tempo': 89.384,
#   'type': 'audio_features',
#   'id': '6hyh19ejxw0MM4DrxzYyAS',
#   'uri': 'spotify:track:6hyh19ejxw0MM4DrxzYyAS',
#   'track_href': 'https://api.spotify.com/v1/tracks/6hyh19ejxw0MM4DrxzYyAS',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hyh19ejxw0MM4DrxzYyAS',
#   'duration_ms': 268459,
#   'time_signature': 3},
#  {'danceability': 0.488,
#   'energy': 0.173,
#   'key': 0,
#   'loudness': -13.508,
#   'mode': 1,
#   'speechiness': 0.029,
#   'acousticness': 0.146,
#   'instrumentalness': 1.4e-05,
#   'liveness': 0.122,
#   'valence': 0.318,
#   'tempo': 143.903,
#   'type': 'audio_features',
#   'id': '2u0lNenprXL72khRm1zrN4',
#   'uri': 'spotify:track:2u0lNenprXL72khRm1zrN4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2u0lNenprXL72khRm1zrN4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2u0lNenprXL72khRm1zrN4',
#   'duration_ms': 325973,
#   'time_signature': 3},
#  {'danceability': 0.599,
#   'energy': 0.29,
#   'key': 4,
#   'loudness': -13.989,
#   'mode': 1,
#   'speechiness': 0.028,
#   'acousticness': 0.17,
#   'instrumentalness': 5.86e-06,
#   'liveness': 0.181,
#   'valence': 0.403,
#   'tempo': 139.955,
#   'type': 'audio_features',
#   'id': '6a8Fk9yFyUQCi2OKKr8dGH',
#   'uri': 'spotify:track:6a8Fk9yFyUQCi2OKKr8dGH',
#   'track_href': 'https://api.spotify.com/v1/tracks/6a8Fk9yFyUQCi2OKKr8dGH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6a8Fk9yFyUQCi2OKKr8dGH',
#   'duration_ms': 207667,
#   'time_signature': 3},
#  {'danceability': 0.626,
#   'energy': 0.718,
#   'key': 11,
#   'loudness': -7.427,
#   'mode': 0,
#   'speechiness': 0.0489,
#   'acousticness': 0.0566,
#   'instrumentalness': 0.00605,
#   'liveness': 0.0643,
#   'valence': 0.837,
#   'tempo': 152.047,
#   'type': 'audio_features',
#   'id': '3skY3IfnJBCqBpchZuqHnN',
#   'uri': 'spotify:track:3skY3IfnJBCqBpchZuqHnN',
#   'track_href': 'https://api.spotify.com/v1/tracks/3skY3IfnJBCqBpchZuqHnN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3skY3IfnJBCqBpchZuqHnN',
#   'duration_ms': 216750,
#   'time_signature': 4},
#  {'danceability': 0.529,
#   'energy': 0.447,
#   'key': 4,
#   'loudness': -9.067,
#   'mode': 0,
#   'speechiness': 0.0316,
#   'acousticness': 0.0328,
#   'instrumentalness': 0.00222,
#   'liveness': 0.093,
#   'valence': 0.0705,
#   'tempo': 120.005,
#   'type': 'audio_features',
#   'id': '5XBBymXE1bVgJxKOVm1b4P',
#   'uri': 'spotify:track:5XBBymXE1bVgJxKOVm1b4P',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XBBymXE1bVgJxKOVm1b4P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XBBymXE1bVgJxKOVm1b4P',
#   'duration_ms': 216507,
#   'time_signature': 4},
#  {'danceability': 0.381,
#   'energy': 0.262,
#   'key': 1,
#   'loudness': -12.544,
#   'mode': 0,
#   'speechiness': 0.0294,
#   'acousticness': 0.724,
#   'instrumentalness': 0.0482,
#   'liveness': 0.179,
#   'valence': 0.256,
#   'tempo': 81.463,
#   'type': 'audio_features',
#   'id': '124M7UXSZx7Nb18dRgJq1r',
#   'uri': 'spotify:track:124M7UXSZx7Nb18dRgJq1r',
#   'track_href': 'https://api.spotify.com/v1/tracks/124M7UXSZx7Nb18dRgJq1r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/124M7UXSZx7Nb18dRgJq1r',
#   'duration_ms': 223347,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.467,
#   'key': 9,
#   'loudness': -8.927,
#   'mode': 0,
#   'speechiness': 0.0313,
#   'acousticness': 0.539,
#   'instrumentalness': 1.13e-06,
#   'liveness': 0.094,
#   'valence': 0.192,
#   'tempo': 127.186,
#   'type': 'audio_features',
#   'id': '696GFgiSEzISVb3oWNDIzn',
#   'uri': 'spotify:track:696GFgiSEzISVb3oWNDIzn',
#   'track_href': 'https://api.spotify.com/v1/tracks/696GFgiSEzISVb3oWNDIzn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/696GFgiSEzISVb3oWNDIzn',
#   'duration_ms': 224646,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.563,
#   'key': 0,
#   'loudness': -5.987,
#   'mode': 1,
#   'speechiness': 0.0301,
#   'acousticness': 0.733,
#   'instrumentalness': 0,
#   'liveness': 0.134,
#   'valence': 0.351,
#   'tempo': 135.929,
#   'type': 'audio_features',
#   'id': '6EXOf2czoRANgzxRwPZe8t',
#   'uri': 'spotify:track:6EXOf2czoRANgzxRwPZe8t',
#   'track_href': 'https://api.spotify.com/v1/tracks/6EXOf2czoRANgzxRwPZe8t',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EXOf2czoRANgzxRwPZe8t',
#   'duration_ms': 345731,
#   'time_signature': 4},
#  {'danceability': 0.15,
#   'energy': 0.00853,
#   'key': 11,
#   'loudness': -21.901,
#   'mode': 1,
#   'speechiness': 0.0371,
#   'acousticness': 0.988,
#   'instrumentalness': 0.846,
#   'liveness': 0.097,
#   'valence': 0.0354,
#   'tempo': 80.256,
#   'type': 'audio_features',
#   'id': '2Yti2tFnRKFQ3Tx0hIyqQM',
#   'uri': 'spotify:track:2Yti2tFnRKFQ3Tx0hIyqQM',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Yti2tFnRKFQ3Tx0hIyqQM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Yti2tFnRKFQ3Tx0hIyqQM',
#   'duration_ms': 227147,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.176,
#   'key': 0,
#   'loudness': -9.596,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'acousticness': 0.869,
#   'instrumentalness': 2.53e-06,
#   'liveness': 0.0989,
#   'valence': 0.233,
#   'tempo': 138.846,
#   'type': 'audio_features',
#   'id': '5jwZ7cVYZUJAKIscWazbUu',
#   'uri': 'spotify:track:5jwZ7cVYZUJAKIscWazbUu',
#   'track_href': 'https://api.spotify.com/v1/tracks/5jwZ7cVYZUJAKIscWazbUu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jwZ7cVYZUJAKIscWazbUu',
#   'duration_ms': 230240,
#   'time_signature': 5},
#  {'danceability': 0.553,
#   'energy': 0.307,
#   'key': 0,
#   'loudness': -9.103,
#   'mode': 1,
#   'speechiness': 0.0287,
#   'acousticness': 0.835,
#   'instrumentalness': 0,
#   'liveness': 0.284,
#   'valence': 0.248,
#   'tempo': 91.996,
#   'type': 'audio_features',
#   'id': '2ZmbLjJ8dpwDt2Ppg9JSg3',
#   'uri': 'spotify:track:2ZmbLjJ8dpwDt2Ppg9JSg3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ZmbLjJ8dpwDt2Ppg9JSg3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ZmbLjJ8dpwDt2Ppg9JSg3',
#   'duration_ms': 260347,
#   'time_signature': 4},
#  {'danceability': 0.803,
#   'energy': 0.506,
#   'key': 9,
#   'loudness': -6.011,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 0.216,
#   'instrumentalness': 2.96e-06,
#   'liveness': 0.101,
#   'valence': 0.574,
#   'tempo': 125.946,
#   'type': 'audio_features',
#   'id': '0tJn1omOgj6BDoXPnykeUc',
#   'uri': 'spotify:track:0tJn1omOgj6BDoXPnykeUc',
#   'track_href': 'https://api.spotify.com/v1/tracks/0tJn1omOgj6BDoXPnykeUc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0tJn1omOgj6BDoXPnykeUc',
#   'duration_ms': 211427,
#   'time_signature': 4},
#  {'danceability': 0.32,
#   'energy': 0.511,
#   'key': 3,
#   'loudness': -7.757,
#   'mode': 1,
#   'speechiness': 0.0679,
#   'acousticness': 0.382,
#   'instrumentalness': 1.19e-05,
#   'liveness': 0.286,
#   'valence': 0.505,
#   'tempo': 92.359,
#   'type': 'audio_features',
#   'id': '1KSa7cIZHYcpwW5INIbX2Z',
#   'uri': 'spotify:track:1KSa7cIZHYcpwW5INIbX2Z',
#   'track_href': 'https://api.spotify.com/v1/tracks/1KSa7cIZHYcpwW5INIbX2Z',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1KSa7cIZHYcpwW5INIbX2Z',
#   'duration_ms': 209920,
#   'time_signature': 4},
#  {'danceability': 0.541,
#   'energy': 0.89,
#   'key': 2,
#   'loudness': -5.195,
#   'mode': 1,
#   'speechiness': 0.0712,
#   'acousticness': 0.201,
#   'instrumentalness': 0.0969,
#   'liveness': 0.359,
#   'valence': 0.594,
#   'tempo': 119.963,
#   'type': 'audio_features',
#   'id': '76NO7hcNUs3IEhmSUz9Z5F',
#   'uri': 'spotify:track:76NO7hcNUs3IEhmSUz9Z5F',
#   'track_href': 'https://api.spotify.com/v1/tracks/76NO7hcNUs3IEhmSUz9Z5F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76NO7hcNUs3IEhmSUz9Z5F',
#   'duration_ms': 357500,
#   'time_signature': 4},
#  {'danceability': 0.609,
#   'energy': 0.136,
#   'key': 4,
#   'loudness': -15.471,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.976,
#   'instrumentalness': 0.0568,
#   'liveness': 0.111,
#   'valence': 0.557,
#   'tempo': 85.161,
#   'type': 'audio_features',
#   'id': '18MgHgbvy3c2jaxdBiemLX',
#   'uri': 'spotify:track:18MgHgbvy3c2jaxdBiemLX',
#   'track_href': 'https://api.spotify.com/v1/tracks/18MgHgbvy3c2jaxdBiemLX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/18MgHgbvy3c2jaxdBiemLX',
#   'duration_ms': 219890,
#   'time_signature': 4},
#  {'danceability': 0.715,
#   'energy': 0.487,
#   'key': 9,
#   'loudness': -7.465,
#   'mode': 1,
#   'speechiness': 0.0377,
#   'acousticness': 0.557,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.596,
#   'tempo': 120.066,
#   'type': 'audio_features',
#   'id': '1cFASgSYREuD9d56twClVv',
#   'uri': 'spotify:track:1cFASgSYREuD9d56twClVv',
#   'track_href': 'https://api.spotify.com/v1/tracks/1cFASgSYREuD9d56twClVv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cFASgSYREuD9d56twClVv',
#   'duration_ms': 157027,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.426,
#   'key': 2,
#   'loudness': -15.643,
#   'mode': 0,
#   'speechiness': 0.0497,
#   'acousticness': 0.9,
#   'instrumentalness': 0.858,
#   'liveness': 0.113,
#   'valence': 0.452,
#   'tempo': 129.865,
#   'type': 'audio_features',
#   'id': '5nQj9cjCynva7oERf9Wg9E',
#   'uri': 'spotify:track:5nQj9cjCynva7oERf9Wg9E',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nQj9cjCynva7oERf9Wg9E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nQj9cjCynva7oERf9Wg9E',
#   'duration_ms': 161293,
#   'time_signature': 3},
#  {'danceability': 0.74,
#   'energy': 0.55,
#   'key': 8,
#   'loudness': -6.598,
#   'mode': 1,
#   'speechiness': 0.115,
#   'acousticness': 0.221,
#   'instrumentalness': 0,
#   'liveness': 0.0746,
#   'valence': 0.581,
#   'tempo': 109.961,
#   'type': 'audio_features',
#   'id': '3otWSmq7tgYweWq9wt1m9E',
#   'uri': 'spotify:track:3otWSmq7tgYweWq9wt1m9E',
#   'track_href': 'https://api.spotify.com/v1/tracks/3otWSmq7tgYweWq9wt1m9E',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3otWSmq7tgYweWq9wt1m9E',
#   'duration_ms': 132867,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '1M2A8o4bqgvwQGvvPdWGvE',
#   'uri': 'spotify:track:1M2A8o4bqgvwQGvvPdWGvE',
#   'track_href': 'https://api.spotify.com/v1/tracks/1M2A8o4bqgvwQGvvPdWGvE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1M2A8o4bqgvwQGvvPdWGvE',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '2Cm5x1rUGolMPlaEnHa3lX',
#   'uri': 'spotify:track:2Cm5x1rUGolMPlaEnHa3lX',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Cm5x1rUGolMPlaEnHa3lX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Cm5x1rUGolMPlaEnHa3lX',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '64IH6D5O3uiSzF2iSER10U',
#   'uri': 'spotify:track:64IH6D5O3uiSzF2iSER10U',
#   'track_href': 'https://api.spotify.com/v1/tracks/64IH6D5O3uiSzF2iSER10U',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64IH6D5O3uiSzF2iSER10U',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '0ymIqSX0qNsjfis9D8SxOn',
#   'uri': 'spotify:track:0ymIqSX0qNsjfis9D8SxOn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0ymIqSX0qNsjfis9D8SxOn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ymIqSX0qNsjfis9D8SxOn',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '4StKkqIsHl4gbM5SwRv64g',
#   'uri': 'spotify:track:4StKkqIsHl4gbM5SwRv64g',
#   'track_href': 'https://api.spotify.com/v1/tracks/4StKkqIsHl4gbM5SwRv64g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4StKkqIsHl4gbM5SwRv64g',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.719,
#   'energy': 0.67,
#   'key': 5,
#   'loudness': -9.118,
#   'mode': 0,
#   'speechiness': 0.0369,
#   'acousticness': 3.54e-05,
#   'instrumentalness': 0.625,
#   'liveness': 0.0957,
#   'valence': 0.313,
#   'tempo': 127.99,
#   'type': 'audio_features',
#   'id': '25QultcArQuKUJUPC5P40A',
#   'uri': 'spotify:track:25QultcArQuKUJUPC5P40A',
#   'track_href': 'https://api.spotify.com/v1/tracks/25QultcArQuKUJUPC5P40A',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25QultcArQuKUJUPC5P40A',
#   'duration_ms': 406429,
#   'time_signature': 4},
#  {'danceability': 0.367,
#   'energy': 0.316,
#   'key': 0,
#   'loudness': -10.831,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.737,
#   'instrumentalness': 0.0219,
#   'liveness': 0.119,
#   'valence': 0.186,
#   'tempo': 175.017,
#   'type': 'audio_features',
#   'id': '1F7MaOg7d89pOCY7HdYqqf',
#   'uri': 'spotify:track:1F7MaOg7d89pOCY7HdYqqf',
#   'track_href': 'https://api.spotify.com/v1/tracks/1F7MaOg7d89pOCY7HdYqqf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1F7MaOg7d89pOCY7HdYqqf',
#   'duration_ms': 212013,
#   'time_signature': 3},
#  {'danceability': 0.252,
#   'energy': 0.732,
#   'key': 9,
#   'loudness': -6.382,
#   'mode': 0,
#   'speechiness': 0.046,
#   'acousticness': 0.192,
#   'instrumentalness': 0.000199,
#   'liveness': 0.172,
#   'valence': 0.358,
#   'tempo': 177.061,
#   'type': 'audio_features',
#   'id': '3hJ0IOOdCwFU8j5ef3tn7K',
#   'uri': 'spotify:track:3hJ0IOOdCwFU8j5ef3tn7K',
#   'track_href': 'https://api.spotify.com/v1/tracks/3hJ0IOOdCwFU8j5ef3tn7K',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3hJ0IOOdCwFU8j5ef3tn7K',
#   'duration_ms': 180013,
#   'time_signature': 3},
#  {'danceability': 0.282,
#   'energy': 0.471,
#   'key': 4,
#   'loudness': -7.12,
#   'mode': 1,
#   'speechiness': 0.032,
#   'acousticness': 0.573,
#   'instrumentalness': 0.736,
#   'liveness': 0.131,
#   'valence': 0.374,
#   'tempo': 144.276,
#   'type': 'audio_features',
#   'id': '4xZ81ezHqdLaKEZ6VAYGcu',
#   'uri': 'spotify:track:4xZ81ezHqdLaKEZ6VAYGcu',
#   'track_href': 'https://api.spotify.com/v1/tracks/4xZ81ezHqdLaKEZ6VAYGcu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4xZ81ezHqdLaKEZ6VAYGcu',
#   'duration_ms': 174013,
#   'time_signature': 3},
#  {'danceability': 0.511,
#   'energy': 0.624,
#   'key': 9,
#   'loudness': -8.674,
#   'mode': 1,
#   'speechiness': 0.0269,
#   'acousticness': 0.319,
#   'instrumentalness': 0.597,
#   'liveness': 0.136,
#   'valence': 0.176,
#   'tempo': 136.004,
#   'type': 'audio_features',
#   'id': '5QDM0XvuEB8d9CS1tWBJz5',
#   'uri': 'spotify:track:5QDM0XvuEB8d9CS1tWBJz5',
#   'track_href': 'https://api.spotify.com/v1/tracks/5QDM0XvuEB8d9CS1tWBJz5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5QDM0XvuEB8d9CS1tWBJz5',
#   'duration_ms': 279013,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.487,
#   'key': 2,
#   'loudness': -6.942,
#   'mode': 1,
#   'speechiness': 0.037,
#   'acousticness': 0.614,
#   'instrumentalness': 0.534,
#   'liveness': 0.0761,
#   'valence': 0.32,
#   'tempo': 121.639,
#   'type': 'audio_features',
#   'id': '2RqbbC8lqoRWxHyd1fZsnZ',
#   'uri': 'spotify:track:2RqbbC8lqoRWxHyd1fZsnZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/2RqbbC8lqoRWxHyd1fZsnZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2RqbbC8lqoRWxHyd1fZsnZ',
#   'duration_ms': 212013,
#   'time_signature': 3},
#  {'danceability': 0.34,
#   'energy': 0.26,
#   'key': 11,
#   'loudness': -9.605,
#   'mode': 1,
#   'speechiness': 0.0311,
#   'acousticness': 0.562,
#   'instrumentalness': 0.646,
#   'liveness': 0.113,
#   'valence': 0.123,
#   'tempo': 105.36,
#   'type': 'audio_features',
#   'id': '6fhQJRSYM6Z6Qah2yi0QVI',
#   'uri': 'spotify:track:6fhQJRSYM6Z6Qah2yi0QVI',
#   'track_href': 'https://api.spotify.com/v1/tracks/6fhQJRSYM6Z6Qah2yi0QVI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6fhQJRSYM6Z6Qah2yi0QVI',
#   'duration_ms': 228013,
#   'time_signature': 4},
#  {'danceability': 0.367,
#   'energy': 0.808,
#   'key': 11,
#   'loudness': -4.068,
#   'mode': 1,
#   'speechiness': 0.0374,
#   'acousticness': 0.312,
#   'instrumentalness': 0.669,
#   'liveness': 0.111,
#   'valence': 0.566,
#   'tempo': 104.825,
#   'type': 'audio_features',
#   'id': '6MuxKhd9Jz1oAp3yuiZ1Gi',
#   'uri': 'spotify:track:6MuxKhd9Jz1oAp3yuiZ1Gi',
#   'track_href': 'https://api.spotify.com/v1/tracks/6MuxKhd9Jz1oAp3yuiZ1Gi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6MuxKhd9Jz1oAp3yuiZ1Gi',
#   'duration_ms': 246013,
#   'time_signature': 4},
#  {'danceability': 0.375,
#   'energy': 0.799,
#   'key': 2,
#   'loudness': -7.23,
#   'mode': 0,
#   'speechiness': 0.0474,
#   'acousticness': 0.0522,
#   'instrumentalness': 0.00648,
#   'liveness': 0.0985,
#   'valence': 0.585,
#   'tempo': 98.95,
#   'type': 'audio_features',
#   'id': '0M03mqzH5CoZ4WNKGemDa4',
#   'uri': 'spotify:track:0M03mqzH5CoZ4WNKGemDa4',
#   'track_href': 'https://api.spotify.com/v1/tracks/0M03mqzH5CoZ4WNKGemDa4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0M03mqzH5CoZ4WNKGemDa4',
#   'duration_ms': 263013,
#   'time_signature': 4},
#  {'danceability': 0.447,
#   'energy': 0.387,
#   'key': 2,
#   'loudness': -7.603,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.894,
#   'instrumentalness': 0.0187,
#   'liveness': 0.112,
#   'valence': 0.454,
#   'tempo': 103.276,
#   'type': 'audio_features',
#   'id': '0Lg5Ff4XAskJvxEEDUnCf1',
#   'uri': 'spotify:track:0Lg5Ff4XAskJvxEEDUnCf1',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Lg5Ff4XAskJvxEEDUnCf1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Lg5Ff4XAskJvxEEDUnCf1',
#   'duration_ms': 227000,
#   'time_signature': 4},
#  {'danceability': 0.466,
#   'energy': 0.494,
#   'key': 5,
#   'loudness': -6.333,
#   'mode': 1,
#   'speechiness': 0.0276,
#   'acousticness': 0.674,
#   'instrumentalness': 0.0873,
#   'liveness': 0.101,
#   'valence': 0.195,
#   'tempo': 133.956,
#   'type': 'audio_features',
#   'id': '7gUdFT0sDafISnRUWsi6mj',
#   'uri': 'spotify:track:7gUdFT0sDafISnRUWsi6mj',
#   'track_href': 'https://api.spotify.com/v1/tracks/7gUdFT0sDafISnRUWsi6mj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7gUdFT0sDafISnRUWsi6mj',
#   'duration_ms': 259013,
#   'time_signature': 3},
#  {'danceability': 0.348,
#   'energy': 0.689,
#   'key': 1,
#   'loudness': -9.012,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.385,
#   'instrumentalness': 0.309,
#   'liveness': 0.0943,
#   'valence': 0.237,
#   'tempo': 91.453,
#   'type': 'audio_features',
#   'id': '2XjAoNdPhlaFPoHpvxDjIx',
#   'uri': 'spotify:track:2XjAoNdPhlaFPoHpvxDjIx',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XjAoNdPhlaFPoHpvxDjIx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XjAoNdPhlaFPoHpvxDjIx',
#   'duration_ms': 318013,
#   'time_signature': 4},
#  {'danceability': 0.595,
#   'energy': 0.647,
#   'key': 5,
#   'loudness': -5.26,
#   'mode': 1,
#   'speechiness': 0.0265,
#   'acousticness': 0.054,
#   'instrumentalness': 0,
#   'liveness': 0.0666,
#   'valence': 0.439,
#   'tempo': 79.988,
#   'type': 'audio_features',
#   'id': '0gQBXd0hZuOwlUJnT4zN6g',
#   'uri': 'spotify:track:0gQBXd0hZuOwlUJnT4zN6g',
#   'track_href': 'https://api.spotify.com/v1/tracks/0gQBXd0hZuOwlUJnT4zN6g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0gQBXd0hZuOwlUJnT4zN6g',
#   'duration_ms': 307592,
#   'time_signature': 4},
#  {'danceability': 0.358,
#   'energy': 0.475,
#   'key': 4,
#   'loudness': -8.658,
#   'mode': 1,
#   'speechiness': 0.0324,
#   'acousticness': 0.184,
#   'instrumentalness': 0,
#   'liveness': 0.0903,
#   'valence': 0.373,
#   'tempo': 113.247,
#   'type': 'audio_features',
#   'id': '3Gzki82KI2pyXG6b2vQE3H',
#   'uri': 'spotify:track:3Gzki82KI2pyXG6b2vQE3H',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Gzki82KI2pyXG6b2vQE3H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Gzki82KI2pyXG6b2vQE3H',
#   'duration_ms': 211813,
#   'time_signature': 4},
#  {'danceability': 0.683,
#   'energy': 0.816,
#   'key': 7,
#   'loudness': -7.094,
#   'mode': 1,
#   'speechiness': 0.0409,
#   'acousticness': 0.0106,
#   'instrumentalness': 3.39e-06,
#   'liveness': 0.434,
#   'valence': 0.809,
#   'tempo': 111.366,
#   'type': 'audio_features',
#   'id': '3e225Z9MPxSfR91SWsF7fH',
#   'uri': 'spotify:track:3e225Z9MPxSfR91SWsF7fH',
#   'track_href': 'https://api.spotify.com/v1/tracks/3e225Z9MPxSfR91SWsF7fH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3e225Z9MPxSfR91SWsF7fH',
#   'duration_ms': 227507,
#   'time_signature': 4},
#  {'danceability': 0.833,
#   'energy': 0.458,
#   'key': 7,
#   'loudness': -6.68,
#   'mode': 1,
#   'speechiness': 0.0339,
#   'acousticness': 0.234,
#   'instrumentalness': 0.00193,
#   'liveness': 0.106,
#   'valence': 0.588,
#   'tempo': 127.588,
#   'type': 'audio_features',
#   'id': '3pdL3ycDSZrx9m1ZZEjX6P',
#   'uri': 'spotify:track:3pdL3ycDSZrx9m1ZZEjX6P',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pdL3ycDSZrx9m1ZZEjX6P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pdL3ycDSZrx9m1ZZEjX6P',
#   'duration_ms': 192107,
#   'time_signature': 4},
#  {'danceability': 0.407,
#   'energy': 0.059,
#   'key': 5,
#   'loudness': -19.073,
#   'mode': 1,
#   'speechiness': 0.0446,
#   'acousticness': 0.996,
#   'instrumentalness': 0.911,
#   'liveness': 0.159,
#   'valence': 0.477,
#   'tempo': 102.56,
#   'type': 'audio_features',
#   'id': '6xZrwNRe5sv1125XQiRNhq',
#   'uri': 'spotify:track:6xZrwNRe5sv1125XQiRNhq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6xZrwNRe5sv1125XQiRNhq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6xZrwNRe5sv1125XQiRNhq',
#   'duration_ms': 136875,
#   'time_signature': 4}]
